# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1. Read the dataset to python environment.**

# %%
data=pd.read_excel('/content/iris (1).xls')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **2. Display the columns in the dataset.**

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# **3.Calculate the mean of each column of the dataset.**

# %%
data.mean(axis=0)
# Out:
# <ipython-input-8-02762784858d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean(axis=0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# **4. Check for the null values present in the dataset.**

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# **5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
plt.bar(data['Classification'],data['PL'])
# Out:
# <BarContainer object of 150 artists>

# %%
plt.boxplot(data[['SL','SW','PL','PW']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ea09a719420>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ea09a719840>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ea09a719180>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7ea09a719d80>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ea09a71a020>,
# ...
#  'means': []}

# %%
plt.hist(data['SL'],color='Blue',rwidth=.8)
plt.hist(data['SW'],color='Brown',rwidth=.8)
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(data['PL'],data['PW'])
plt.title('PL to PW',fontsize=16)
# Out:
# Text(0.5, 1.0, 'PL to PW')

# %%
slice_data=data[['SL','SW','PL','PW']]

# %%
sns.heatmap(slice_data.corr(),annot=True)
# Out:
# <Axes: >
